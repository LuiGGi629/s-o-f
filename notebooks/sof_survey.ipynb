# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
os.chdir('/Users/wojtek/PycharmProjects/s-o-f/')
os.getcwd()
# Out:
# '/Users/wojtek/PycharmProjects/s-o-f'

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %% [markdown]
# # Indexes - How to Set, Reset, and Use Indexes

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# DevType                 Which of the following describe you? Please se...
# YearsCode               Including any education, how many years have y...
# Age1stCode              At what age did you write your first line of c...
# YearsCodePro            How many years have you coded professionally (...
# CareerSat               Overall, how satisfied are you with your caree...
# JobSat                  How satisfied are you with your current job? (...
# MgrIdiot                How confident are you that your manager knows ...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrWant                 Do you want to become a manager yourself in th...
# JobSeek                 Which of the following best describes your cur...
# LastHireDate            When was the last time that you took a job wit...
# LastInt                 In your most recent successful job interview (...
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# JobFactors              Imagine that you are deciding between two job ...
# ResumeUpdate            Think back to the last time you updated your r...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# CompTotal               What is your current total compensation (salar...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# ConvertedComp           Salary converted to annual USD salaries using ...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkPlan                          How structured or planned is your work?
# WorkChallenge           Of these options, what are your greatest chall...
# WorkRemote                                How often do you work remotely?
# WorkLoc                                   Where would you prefer to work?
# ImpSyn                  For the specific work you do, and the years of...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# UnitTests               Does your company regularly employ unit tests ...
# PurchaseHow             How does your company make decisions about pur...
# PurchaseWhat            What level of influence do you, personally, ha...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# DatabaseWorkedWith      Which of the following database environments h...
# DatabaseDesireNextYear  Which of the following database environments h...
# PlatformWorkedWith      Which of the following platforms have you done...
# PlatformDesireNextYear  Which of the following platforms have you done...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# DevEnviron              Which development environment(s) do you use re...
# OpSys                   What is the primary operating system in which ...
# Containers              How do you use containers (Docker, Open Contai...
# BlockchainOrg           How is your organization thinking about or imp...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BetterLife              Do you think people born today will have a bet...
# ITperson                 Are you the "IT support person" for your family?
# OffOn                         Have you tried turning it off and on again?
# SocialMedia                   What social media site do you use the most?
# Extraversion              Do you prefer online chat or IRL conversations?
# ScreenName                                           What do you call it?
# SOVisit1st              To the best of your memory, when did you first...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# SOFindAnswer            On average, how many times a week do you find ...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOAccount                           Do you have a Stack Overflow account?
# SOPartFreq              How frequently would you say you participate i...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# SOComm                  Do you consider yourself a member of the Stack...
# WelcomeChange           Compared to last year, how welcome do you feel...
# SONewContent            Would you like to see any of the following on ...
# Age                     What is your age (in years)? If you prefer not...
# Gender                  Which of the following do you currently identi...
# Trans                                     Do you identify as transgender?
# Sexuality               Which of the following do you currently identi...
# Ethnicity               Which of the following do you identify as? Ple...
# Dependents              Do you have any dependents (e.g., children, el...
# SurveyLength            How do you feel about the length of the survey...
# SurveyEase              How easy or difficult was this survey to compl...

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(inplace=True)
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# Country                         In which country do you currently reside?
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear  Which of the following database environments h...
# DatabaseWorkedWith      Which of the following database environments h...
# Dependents              Do you have any dependents (e.g., children, el...
# DevEnviron              Which development environment(s) do you use re...
# DevType                 Which of the following describe you? Please se...
# EdLevel                 Which of the following best describes the high...
# EduOther                Which of the following types of non-degree edu...
# Employment              Which of the following best describes your cur...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# Ethnicity               Which of the following do you identify as? Ple...
# Extraversion              Do you prefer online chat or IRL conversations?
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# Gender                  Which of the following do you currently identi...
# Hobbyist                                          Do you code as a hobby?
# ITperson                 Are you the "IT support person" for your family?
# ImpSyn                  For the specific work you do, and the years of...
# JobFactors              Imagine that you are deciding between two job ...
# JobSat                  How satisfied are you with your current job? (...
# JobSeek                 Which of the following best describes your cur...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LastHireDate            When was the last time that you took a job wit...
# LastInt                 In your most recent successful job interview (...
# MainBranch              Which of the following options best describes ...
# MgrIdiot                How confident are you that your manager knows ...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrWant                 Do you want to become a manager yourself in th...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# OffOn                         Have you tried turning it off and on again?
# OpSys                   What is the primary operating system in which ...
# OpenSource              How do you feel about the quality of open sour...
# OpenSourcer                   How often do you contribute to open source?
# OrgSize                 Approximately how many people are employed by ...
# PlatformDesireNextYear  Which of the following platforms have you done...
# PlatformWorkedWith      Which of the following platforms have you done...
# PurchaseHow             How does your company make decisions about pur...
# PurchaseWhat            What level of influence do you, personally, ha...
# Respondent              Randomized respondent ID number (not in order ...
# ResumeUpdate            Think back to the last time you updated your r...
# SOAccount                           Do you have a Stack Overflow account?
# SOComm                  Do you consider yourself a member of the Stack...
# SOFindAnswer            On average, how many times a week do you find ...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# SONewContent            Would you like to see any of the following on ...
# SOPartFreq              How frequently would you say you participate i...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOVisit1st              To the best of your memory, when did you first...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# ScreenName                                           What do you call it?
# Sexuality               Which of the following do you currently identi...
# SocialMedia                   What social media site do you use the most?
# Student                 Are you currently enrolled in a formal, degree...
# SurveyEase              How easy or difficult was this survey to compl...
# SurveyLength            How do you feel about the length of the survey...
# Trans                                     Do you identify as transgender?
# UndergradMajor          What was your main or most important field of ...
# UnitTests               Does your company regularly employ unit tests ...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WorkChallenge           Of these options, what are your greatest chall...
# WorkLoc                                   Where would you prefer to work?
# WorkPlan                          How structured or planned is your work?
# WorkRemote                                How often do you work remotely?
# WorkWeekHrs              On average, how many hours per week do you work?
# YearsCode               Including any education, how many years have y...
# YearsCodePro            How many years have you coded professionally (...

# %%
df.shape
# Out:
# (88883, 84)

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[1, 'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[1:3, 'Hobbyist']
# Out:
# Respondent
# 1    Yes
# 2     No
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[1:3, 'Hobbyist':'Employment']
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment
# Respondent
# 1           Not employed, and not looking for work
# 2               Not employed, but looking for work
# 3                               Employed full-time

# %% [markdown]
# # Filtering - Using Conditionals to Filter Rows and Columns

# %%
high_salary = (df['ConvertedComp'] > 70_000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 6                   Canada                                         Java;R;SQL
# 9              New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 13           United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 16          United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 22           United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                    ...                                                ...
# 88876        United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877        United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878        United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88879              Finland                   Bash/Shell/PowerShell;C++;Python
# 88882          Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#             ConvertedComp
# Respondent
# 6                366420.0
# 9                 95179.0
# 13                90000.0
# 16               455352.0
# 22               103000.0
# ...                   ...
# 88876            180000.0
# 88877           2000000.0
# 88878            130000.0
# 88879             82488.0
# 88882            588012.0
#
# [22289 rows x 3 columns]

# %%
countries = ['United Kingdom', 'United States', 'Canada', 'Germany', 'India', 'Poland']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, ['Country']]
# Out:
#                    Country
# Respondent
# 1           United Kingdom
# 4            United States
# 6                   Canada
# 8                    India
# 10                   India
# ...                    ...
# 85642        United States
# 85961       United Kingdom
# 86012                India
# 88282        United States
# 88377               Canada
#
# [46930 rows x 1 columns]

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 3                                                 HTML/CSS
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88377                        HTML/CSS;JavaScript;Other(s):
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 1                          HTML/CSS;Java;JavaScript;Python
# 2                                      C++;HTML/CSS;Python
# 4                                      C;C++;C#;Python;SQL
# 5              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 8        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 84539    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 85738      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 86566      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 87739             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88212                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# # Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD'].head()
# Out:
# Respondent
# 1        NaN
# 2        NaN
# 3     8820.0
# 4    61000.0
# 5        NaN
# Name: SalaryUSD, dtype: float64

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': 1, 'No': 0})
df['Hobbyist'].head()
# Out:
# Respondent
# 1    1
# 2    0
# 3    1
# 4    0
# 5    1
# Name: Hobbyist, dtype: int64

# %% [markdown]
# # Add/Remove Rows and Columns From DataFrames

# %% [markdown]
# # Sorting Data

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[True, False], inplace=True)
df[['Country', 'SalaryUSD']].head(5)
# Out:
#                 Country  SalaryUSD
# Respondent
# 63129       Afghanistan  1000000.0
# 50499       Afghanistan   153216.0
# 39258       Afghanistan    19152.0
# 58450       Afghanistan    17556.0
# 7085        Afghanistan    14364.0

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 22013    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(5, 'SalaryUSD')
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession         1
# 87896                          I am a developer by profession         1
# 28243                          I am a developer by profession         1
# 72732       I am not primarily a developer, but I write co...         0
# 22013                          I am a developer by profession         1
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# 87896                                 Less than once per year
# 28243                              Once a month or more often
# 72732       Less than once a month but more than once per ...
# 22013                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 25983       OSS is, on average, of HIGHER quality than pro...
# 87896       The quality of OSS and closed source software ...
# 28243       OSS is, on average, of HIGHER quality than pro...
# 72732       OSS is, on average, of LOWER quality than prop...
# 22013       The quality of OSS and closed source software ...
#
#                                                    Employment  Country  \
# Respondent
# 25983                                      Employed full-time   Canada
# 87896                                      Employed full-time  Germany
# 28243       Independent contractor, freelancer, or self-em...    India
# 72732                                                     NaN    India
# 22013                                      Employed full-time    India
#
#                    Student                                      EdLevel  \
# Respondent
# 25983                   No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87896                   No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 28243                   No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 72732       Yes, full-time     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 22013                   No           Professional degree (JD, MD, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 25983       Computer science, computer engineering, or sof...
# 87896       Computer science, computer engineering, or sof...
# 28243       Computer science, computer engineering, or sof...
# 72732       Computer science, computer engineering, or sof...
# 22013       A natural science (ex. biology, chemistry, phy...
#
#                                                      EduOther  \
# Respondent
# 25983       Received on-the-job training in software devel...
# 87896       Taken an online course in programming or softw...
# 28243       Taken an online course in programming or softw...
# 72732                     Contributed to open source software
# 22013       Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 25983       10,000 or more employees
# 87896                  2-9 employees
# 28243                  2-9 employees
# 72732                            NaN
# 22013                  2-9 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 25983                                   Developer, full-stack         8
# 87896                                   Developer, full-stack         9
# 28243       Developer, back-end;Developer, full-stack;Deve...        25
# 72732                                                     NaN         4
# 22013       Academic researcher;Data scientist or machine ...         3
#
#            Age1stCode YearsCodePro                           CareerSat  \
# Respondent
# 25983              16            2                      Very satisfied
# 87896              17            8                      Very satisfied
# 28243               9           14  Neither satisfied nor dissatisfied
# 72732              20            5                  Slightly satisfied
# 22013              26            3                      Very satisfied
#
#                                         JobSat            MgrIdiot MgrMoney  \
# Respondent
# 25983                           Very satisfied  Somewhat confident       No
# 87896                           Very satisfied  Somewhat confident       No
# 28243       Neither satisfied nor dissatisfied                 NaN      NaN
# 72732                       Slightly satisfied                 NaN      NaN
# 22013                           Very satisfied                 NaN      NaN
#
#                            MgrWant  \
# Respondent
# 25983                           No
# 87896       I am already a manager
# 28243                          NaN
# 72732                          NaN
# 22013                          NaN
#
#                                                       JobSeek  \
# Respondent
# 25983       I’m not actively looking, but I am open to new...
# 87896            I am not interested in new job opportunities
# 28243       I’m not actively looking, but I am open to new...
# 72732                         I am actively looking for a job
# 22013            I am not interested in new job opportunities
#
#                      LastHireDate  \
# Respondent
# 25983               3-4 years ago
# 87896       More than 4 years ago
# 28243               1-2 years ago
# 72732       More than 4 years ago
# 22013               3-4 years ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 25983       Solve a brain-teaser style puzzle;Interview wi...       No
# 87896       Write any code;Interview with people in senior...       No
# 28243       Interview with people in peer roles;Interview ...      Yes
# 72732                                          Write any code       No
# 22013       Write code by hand (e.g., on a whiteboard);Com...       No
#
#                                                    JobFactors  \
# Respondent
# 25983       Remote work options;Opportunities for professi...
# 87896       Office environment or company culture;Diversit...
# 28243       Financial performance or funding status of the...
# 72732       Remote work options;Opportunities for professi...
# 22013       Financial performance or funding status of the...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 25983        My job status changed (promotion, new job, etc.)            USD
# 87896       Something else changed (education, award, medi...            USD
# 28243       I heard about a job opportunity (from a recrui...            USD
# 72732                        I was preparing for a job search            USD
# 22013       Something else changed (education, award, medi...            USD
#
#                     CurrencyDesc  CompTotal CompFreq  SalaryUSD  WorkWeekHrs  \
# Respondent
# 25983       United States dollar    65500.0   Weekly  2000000.0         45.0
# 87896       United States dollar    55000.0   Weekly  2000000.0         40.0
# 28243       United States dollar  2000000.0   Yearly  2000000.0         20.0
# 72732       United States dollar    80000.0   Weekly  2000000.0         40.0
# 22013       United States dollar  1500000.0   Weekly  2000000.0         50.0
#
#                                                      WorkPlan  \
# Respondent
# 25983       There is a schedule and/or spec (made by me or...
# 87896       There is a schedule and/or spec (made by me or...
# 28243       There is a schedule and/or spec (made by me or...
# 72732       There is a schedule and/or spec (made by me or...
# 22013       There's no schedule or spec; I work on what se...
#
#                                                 WorkChallenge  \
# Respondent
# 25983       Being tasked with non-development work;Meeting...
# 87896       Being tasked with non-development work;Meeting...
# 28243       Being tasked with non-development work;Not eno...
# 72732       Lack of support from management;Meetings;Time ...
# 22013       Inadequate access to necessary tools;Meetings;...
#
#                                                    WorkRemote WorkLoc  \
# Respondent
# 25983                                   A few days each month  Office
# 87896       All or almost all the time (I'm full-time remote)    Home
# 28243       All or almost all the time (I'm full-time remote)  Office
# 72732                        Less than once per month / Never  Office
# 22013       All or almost all the time (I'm full-time remote)    Home
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 25983                      Average  Yes, because I see value in code review
# 87896       A little above average  Yes, because I see value in code review
# 28243            Far above average  Yes, because I see value in code review
# 72732       A little above average  Yes, because I see value in code review
# 22013       A little below average  Yes, because I see value in code review
#
#             CodeRevHrs                      UnitTests  \
# Respondent
# 25983              2.0  Yes, it's part of our process
# 87896              3.0      No, but I think we should
# 28243              NaN                            NaN
# 72732             10.0  Yes, it's part of our process
# 22013             10.0  Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 25983       Developers and management have nearly equal in...
# 87896       Developers and management have nearly equal in...
# 28243                                                     NaN
# 72732                                                Not sure
# 22013       Developers typically have the most influence o...
#
#                                 PurchaseWhat  \
# Respondent
# 25983          I have little or no influence
# 87896       I have a great deal of influence
# 28243                                    NaN
# 72732          I have little or no influence
# 22013       I have a great deal of influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 25983       Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 87896                             HTML/CSS;JavaScript;PHP;SQL
# 28243               C++;C#;Java;JavaScript;Objective-C;Python
# 72732                                         Java;Python;SQL
# 22013       Assembly;Bash/Shell/PowerShell;C;C++;Java;Java...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 25983       Bash/Shell/PowerShell;C#;F#;Python;SQL;TypeScript
# 87896             HTML/CSS;JavaScript;PHP;Ruby;SQL;TypeScript
# 28243                                                C;C++;C#
# 72732                                                     NaN
# 22013                                            Python;Swift
#
#                                            DatabaseWorkedWith  \
# Respondent
# 25983                              Microsoft SQL Server;MySQL
# 87896                                MariaDB;MySQL;PostgreSQL
# 28243                                       PostgreSQL;SQLite
# 72732       MongoDB;Microsoft SQL Server;MySQL;Oracle;Post...
# 22013                   Cassandra;Microsoft SQL Server;Oracle
#
#                 DatabaseDesireNextYear  \
# Respondent
# 25983       Microsoft SQL Server;MySQL
# 87896         MariaDB;MySQL;PostgreSQL
# 28243                           SQLite
# 72732                            MySQL
# 22013                        Cassandra
#
#                                            PlatformWorkedWith  \
# Respondent
# 25983       AWS;Docker;Heroku;Linux;MacOS;Raspberry Pi;Win...
# 87896                                               WordPress
# 28243                           Android;AWS;iOS;MacOS;Windows
# 72732                                         Android;Windows
# 22013       Android;Arduino;Google Cloud Platform;IBM Clou...
#
#                     PlatformDesireNextYear     WebFrameWorkedWith  \
# Respondent
# 25983       AWS;Docker;Linux;MacOS;Windows     Angular/Angular.js
# 87896                                  NaN  jQuery;Laravel;Vue.js
# 28243                        Android;Linux                    NaN
# 72732                           AWS;Docker                    NaN
# 22013          IBM Cloud or Watson;Windows                 jQuery
#
#                           WebFrameDesireNextYear       MiscTechWorkedWith  \
# Respondent
# 25983          Angular/Angular.js;Flask;React.js   .NET;.NET Core;Node.js
# 87896       Express;Laravel;Ruby on Rails;Vue.js                      NaN
# 28243                                        NaN  Node.js;Pandas;Unity 3D
# 72732                Angular/Angular.js;React.js                      NaN
# 22013                                        NaN               TensorFlow
#
#             MiscTechDesireNextYear  \
# Respondent
# 25983            .NET Core;Node.js
# 87896                      Node.js
# 28243       Unity 3D;Unreal Engine
# 72732                          NaN
# 22013                   TensorFlow
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 25983       Notepad++;Sublime Text;Vim;Visual Studio;Visua...      Windows
# 87896                     Sublime Text;Vim;Visual Studio Code  Linux-based
# 28243       Android Studio;Coda;PyCharm;Visual Studio;Visu...        MacOS
# 72732                               Eclipse;Notepad++;PyCharm      Windows
# 22013                        Visual Studio;Visual Studio Code      Windows
#
#                          Containers                        BlockchainOrg  \
# Respondent
# 25983        Development;Production                                  NaN
# 87896       I do not use containers                           Not at all
# 28243       I do not use containers                                  NaN
# 72732                       Testing                                  NaN
# 22013                   Development  Implementing our own cryptocurrency
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 25983       Useful for decentralized currency (i.e., Bitcoin)         No
# 87896       Useful for immutable record keeping outside of...         No
# 28243                       An irresponsible use of resources         No
# 72732                                                     NaN        Yes
# 22013       Useful across many domains and could change ma...        Yes
#
#            ITperson OffOn               SocialMedia              Extraversion  \
# Respondent
# 25983           Yes   Yes                    Reddit  In real life (in person)
# 87896           Yes   Yes                   Twitter                    Online
# 28243           Yes    No  I don't use social media  In real life (in person)
# 72732           Yes    No                  WhatsApp                   Neither
# 22013           Yes    No                   YouTube                    Online
#
#              ScreenName SOVisit1st                      SOVisitFreq  \
# Respondent
# 25983          Username       2013            Daily or almost daily
# 87896            Handle       2011            Daily or almost daily
# 28243          Username       2008            Daily or almost daily
# 72732               NaN       2017  A few times per month or weekly
# 22013       Screen Name        NaN             A few times per week
#
#                                                     SOVisitTo  \
# Respondent
# 25983       Find answers to specific questions;Learn how t...
# 87896                      Find answers to specific questions
# 28243                      Find answers to specific questions
# 72732       Get a sense of belonging to the developer comm...
# 22013                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 25983                1-2 times per week      Stack Overflow was much faster
# 87896                3-5 times per week      Stack Overflow was much faster
# 28243       More than 10 times per week      Stack Overflow was much faster
# 72732                1-2 times per week  Stack Overflow was slightly faster
# 22013                1-2 times per week      Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 25983       11-30 minutes       Yes
# 87896        0-10 minutes       Yes
# 28243         60+ minutes       Yes
# 72732       11-30 minutes       Yes
# 22013         60+ minutes       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 25983                     Less than once per month or monthly
# 87896                     Less than once per month or monthly
# 28243                                  Multiple times per day
# 72732                         A few times per month or weekly
# 22013       I have never participated in Q&A on Stack Over...
#
#                                                        SOJobs  \
# Respondent
# 25983       No, I knew that Stack Overflow had a job board...
# 87896       No, I knew that Stack Overflow had a job board...
# 28243                                                     Yes
# 72732                                                     Yes
# 22013                                                     Yes
#
#                                                      EntTeams  \
# Respondent
# 25983                     No, and I don't know what those are
# 87896       No, I've heard of them, but I am not part of a...
# 28243                     No, and I don't know what those are
# 72732                     No, and I don't know what those are
# 22013                                                     Yes
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 25983        No, not really  Just as welcome now as I felt last year
# 87896        No, not really  Just as welcome now as I felt last year
# 28243       Yes, definitely    A lot less welcome now than last year
# 72732              Not sure    A lot less welcome now than last year
# 22013       Yes, definitely    A lot more welcome now than last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 25983                                                     NaN  24.0    Man
# 87896       Tech articles written by other developers;Tech...  32.0    Man
# 28243                     Tech meetups or events in your area   NaN    NaN
# 72732       Tech articles written by other developers;Tech...   NaN    Man
# 22013       Tech articles written by other developers;Indu...   NaN    Man
#
#            Trans                Sexuality                     Ethnicity  \
# Respondent
# 25983         No  Straight / Heterosexual  White or of European descent
# 87896         No           Gay or Lesbian  White or of European descent
# 28243        NaN  Straight / Heterosexual                           NaN
# 72732         No                      NaN                           NaN
# 22013         No  Straight / Heterosexual                           NaN
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 25983              No  Appropriate in length                        Easy
# 87896              No  Appropriate in length  Neither easy nor difficult
# 28243             Yes              Too short                        Easy
# 72732             Yes               Too long                        Easy
# 22013             Yes               Too long                        Easy

# %%
df.nsmallest(5, 'SalaryUSD')
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 28638       I am a developer by profession         1
# 722         I am a developer by profession         0
# 13825       I am a developer by profession         1
# 40913       I am a developer by profession         1
# 69049       I am a developer by profession         0
#
#                                                   OpenSourcer  \
# Respondent
# 28638       Less than once a month but more than once per ...
# 722         Less than once a month but more than once per ...
# 13825                                                   Never
# 40913                                 Less than once per year
# 69049                                                   Never
#
#                                                    OpenSource  \
# Respondent
# 28638       OSS is, on average, of HIGHER quality than pro...
# 722         The quality of OSS and closed source software ...
# 13825       The quality of OSS and closed source software ...
# 40913       The quality of OSS and closed source software ...
# 69049       The quality of OSS and closed source software ...
#
#                                                    Employment      Country  \
# Respondent
# 28638       Independent contractor, freelancer, or self-em...  Afghanistan
# 722                                                       NaN  Afghanistan
# 13825                                                     NaN      Algeria
# 40913                                      Employed full-time      Armenia
# 69049       Independent contractor, freelancer, or self-em...    Australia
#
#            Student                                    EdLevel  \
# Respondent
# 28638          NaN  Other doctoral degree (Ph.D, Ed.D., etc.)
# 722            NaN                                        NaN
# 13825          NaN                                        NaN
# 40913           No   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 69049           No   Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 28638                                I never declared a major
# 722                                                       NaN
# 13825                                                     NaN
# 40913       Computer science, computer engineering, or sof...
# 69049       Computer science, computer engineering, or sof...
#
#                                                      EduOther        OrgSize  \
# Respondent
# 28638                                                     NaN            NaN
# 722                                                       NaN            NaN
# 13825                                                     NaN            NaN
# 40913       Taught yourself a new language, framework, or ...  2-9 employees
# 69049       Received on-the-job training in software devel...  2-9 employees
#
#                                                       DevType  \
# Respondent
# 28638                                                     NaN
# 722                                                       NaN
# 13825                                                     NaN
# 40913       Developer, desktop or enterprise applications;...
# 69049               Developer, full-stack;Engineering manager
#
#                    YearsCode            Age1stCode      YearsCodePro  \
# Respondent
# 28638                     36                    13                16
# 722         Less than 1 year  Younger than 5 years  Less than 1 year
# 13825                     13                    83  Less than 1 year
# 40913                      7                    15                 4
# 69049                     17                    12                14
#
#                      CareerSat              JobSat        MgrIdiot  MgrMoney  \
# Respondent
# 28638        Very dissatisfied   Very dissatisfied             NaN       NaN
# 722             Very satisfied      Very satisfied             NaN       NaN
# 13825        Very dissatisfied      Very satisfied             NaN       NaN
# 40913       Slightly satisfied  Slightly satisfied  Very confident  Not sure
# 69049       Slightly satisfied  Slightly satisfied             NaN       NaN
#
#              MgrWant                                            JobSeek  \
# Respondent
# 28638            NaN       I am not interested in new job opportunities
# 722              NaN       I am not interested in new job opportunities
# 13825            NaN                    I am actively looking for a job
# 40913       Not sure       I am not interested in new job opportunities
# 69049            NaN  I’m not actively looking, but I am open to new...
#
#                                                  LastHireDate  \
# Respondent
# 28638                                                     NaN
# 722         NA - I am an independent contractor or self em...
# 13825       NA - I am an independent contractor or self em...
# 40913                                    Less than a year ago
# 69049                                           1-2 years ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 28638                                                     NaN      NaN
# 722                                                       NaN       No
# 13825       Complete a take-home project;Solve a brain-tea...      Yes
# 40913       Write any code;Write code by hand (e.g., on a ...       No
# 69049       Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 28638                                                     NaN
# 722                                                       NaN
# 13825       Financial performance or funding status of the...
# 40913       Industry that I'd be working in;Languages, fra...
# 69049       Specific department or team I'd be working on;...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 28638                                                     NaN            AFN
# 722         I heard about a job opportunity (from a recrui...            AFN
# 13825       Something else changed (education, award, medi...            AFN
# 40913       Something else changed (education, award, medi...            AMD
# 69049        My job status changed (promotion, new job, etc.)            AUD
#
#                  CurrencyDesc  CompTotal CompFreq  SalaryUSD  WorkWeekHrs  \
# Respondent
# 28638          Afghan afghani        3.0  Monthly        0.0          2.0
# 722            Afghan afghani        1.0   Yearly        0.0          1.0
# 13825          Afghan afghani        1.0   Yearly        0.0        168.0
# 40913           Armenian dram        0.0  Monthly        0.0         40.0
# 69049       Australian dollar        0.0   Yearly        0.0         25.0
#
#                                                      WorkPlan  \
# Respondent
# 28638                                                     NaN
# 722                                                       NaN
# 13825                                                     NaN
# 40913       There's no schedule or spec; I work on what se...
# 69049       There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 28638                                                     NaN
# 722                                                       NaN
# 13825       Being tasked with non-development work;Non-wor...
# 40913       Meetings;Non-work commitments (parenting, scho...
# 69049       Lack of support from management;Time spent com...
#
#                                                    WorkRemote  \
# Respondent
# 28638                                                     NaN
# 722                          Less than once per month / Never
# 13825                                     About half the time
# 40913       Less than half the time, but at least one day ...
# 69049       All or almost all the time (I'm full-time remote)
#
#                                                    WorkLoc  \
# Respondent
# 28638                                                  NaN
# 722         Other place, such as a coworking space or cafe
# 13825                                                 Home
# 40913                                               Office
# 69049                                                 Home
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 28638                          NaN                                      NaN
# 722              Far above average  Yes, because I see value in code review
# 13825            Far above average                                       No
# 40913       A little above average  Yes, because I see value in code review
# 69049       A little above average  Yes, because I see value in code review
#
#             CodeRevHrs                      UnitTests  \
# Respondent
# 28638              NaN                            NaN
# 722                1.0      No, and I'm glad we don't
# 13825              NaN  Yes, it's part of our process
# 40913              3.0      No, and I'm glad we don't
# 69049              1.0                            NaN
#
#                                                   PurchaseHow  \
# Respondent
# 28638                                                     NaN
# 722                                                       NaN
# 13825                                                     NaN
# 40913       Developers and management have nearly equal in...
# 69049                                                     NaN
#
#                                 PurchaseWhat  \
# Respondent
# 28638                                    NaN
# 722            I have little or no influence
# 13825       I have a great deal of influence
# 40913       I have a great deal of influence
# 69049                                    NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 28638       Bash/Shell/PowerShell;C;C++;Java;Objective-C;O...
# 722                                                       NaN
# 13825                                               Other(s):
# 40913       Bash/Shell/PowerShell;C;C++;Java;JavaScript;Py...
# 69049       Bash/Shell/PowerShell;C;C#;Go;HTML/CSS;JavaScr...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 28638       Bash/Shell/PowerShell;C;C++;Java;Objective-C;O...
# 722                                                       NaN
# 13825                                               Other(s):
# 40913                        C;C++;Java;Python;SQL;TypeScript
# 69049        Dart;Elixir;JavaScript;Kotlin;Python;R;Ruby;Rust
#
#                                    DatabaseWorkedWith  \
# Respondent
# 28638                                    MySQL;SQLite
# 722                                               NaN
# 13825                                       Other(s):
# 40913       Elasticsearch;MariaDB;MongoDB;MySQL;Redis
# 69049                               PostgreSQL;SQLite
#
#                 DatabaseDesireNextYear  \
# Respondent
# 28638                     MySQL;SQLite
# 722                                NaN
# 13825                        Other(s):
# 40913            MariaDB;MongoDB;MySQL
# 69049       Cassandra;PostgreSQL;Redis
#
#                                            PlatformWorkedWith  \
# Respondent
# 28638                                 Android;iOS;Linux;MacOS
# 722                                                       NaN
# 13825                                               Other(s):
# 40913       Arduino;AWS;Docker;Linux;MacOS;Raspberry Pi;Sl...
# 69049       Android;Arduino;Google Cloud Platform;iOS;Linu...
#
#                                        PlatformDesireNextYear  \
# Respondent
# 28638                                       Android;iOS;Linux
# 722                                                       NaN
# 13825                                               Other(s):
# 40913                        Arduino;Linux;MacOS;Raspberry Pi
# 69049       Google Cloud Platform;Heroku;Kubernetes;Linux;...
#
#               WebFrameWorkedWith WebFrameDesireNextYear  \
# Respondent
# 28638                     jQuery                    NaN
# 722                          NaN                    NaN
# 13825                  Other(s):              Other(s):
# 40913       ASP.NET;Django;Flask           Django;Flask
# 69049              Ruby on Rails   Ruby on Rails;Vue.js
#
#                                MiscTechWorkedWith  \
# Respondent
# 28638                         TensorFlow;Unity 3D
# 722                                           NaN
# 13825                                   Other(s):
# 40913       .NET;Node.js;TensorFlow;Torch/PyTorch
# 69049                           .NET;React Native
#
#                                 MiscTechDesireNextYear  \
# Respondent
# 28638                       Hadoop;TensorFlow;Unity 3D
# 722                                                NaN
# 13825                                        Other(s):
# 40913                                          Node.js
# 69049       Ansible;Flutter;Hadoop;Pandas;React Native
#
#                                                  DevEnviron        OpSys  \
# Respondent
# 28638                                                 Emacs  Linux-based
# 722                                                     NaN          NaN
# 13825                                                   NaN          NaN
# 40913           IntelliJ;IPython / Jupyter;Sublime Text;Vim  Linux-based
# 69049       IntelliJ;Visual Studio;Visual Studio Code;Xcode        MacOS
#
#                          Containers BlockchainOrg  \
# Respondent
# 28638       I do not use containers           NaN
# 722                             NaN           NaN
# 13825       I do not use containers           NaN
# 40913                    Production    Not at all
# 69049                    Production           NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 28638       Useful for immutable record keeping outside of...         No
# 722                                                       NaN         No
# 13825                       An irresponsible use of resources         No
# 40913                                           A passing fad         No
# 69049                                           A passing fad         No
#
#             ITperson  OffOn SocialMedia              Extraversion ScreenName  \
# Respondent
# 28638            Yes     No         NaN  In real life (in person)   Username
# 722             SIGH  What?         NaN                   Neither        NaN
# 13825            Yes    Yes         NaN                   Neither        NaN
# 40913           SIGH    Yes    Facebook  In real life (in person)   Username
# 69049       Also Yes    Yes      Reddit  In real life (in person)   Username
#
#            SOVisit1st                      SOVisitFreq  \
# Respondent
# 28638            2008            Daily or almost daily
# 722              2008           Multiple times per day
# 13825            2015  A few times per month or weekly
# 40913            2013           Multiple times per day
# 69049            2008             A few times per week
#
#                                                     SOVisitTo  \
# Respondent
# 28638                      Find answers to specific questions
# 722                                                       NaN
# 13825                      Find answers to specific questions
# 40913       Find answers to specific questions;Learn how t...
# 69049                      Find answers to specific questions
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 28638               6-10 times per week  The other resource was much faster
# 722         More than 10 times per week  The other resource was much faster
# 13825                1-2 times per week            They were about the same
# 40913                3-5 times per week      Stack Overflow was much faster
# 69049                3-5 times per week      Stack Overflow was much faster
#
#             SOHowMuchTime                  SOAccount  \
# Respondent
# 28638       11-30 minutes                        Yes
# 722           60+ minutes  Not sure / can't remember
# 13825                 NaN                        Yes
# 40913        0-10 minutes                        Yes
# 69049       11-30 minutes  Not sure / can't remember
#
#                                                    SOPartFreq  \
# Respondent
# 28638                     Less than once per month or monthly
# 722                                                       NaN
# 13825       I have never participated in Q&A on Stack Over...
# 40913                     Less than once per month or monthly
# 69049                                                     NaN
#
#                                                        SOJobs  \
# Respondent
# 28638                                                     Yes
# 722                                                       Yes
# 13825       No, I knew that Stack Overflow had a job board...
# 40913       No, I knew that Stack Overflow had a job board...
# 69049       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams          SOComm  \
# Respondent
# 28638       No, I've heard of them, but I am not part of a...  No, not at all
# 722                                                       Yes        Not sure
# 13825                     No, and I don't know what those are  No, not at all
# 40913       No, I've heard of them, but I am not part of a...  No, not really
# 69049       No, I've heard of them, but I am not part of a...  No, not at all
#
#                                                 WelcomeChange  \
# Respondent
# 28638                   A lot less welcome now than last year
# 722         Not applicable - I did not use Stack Overflow ...
# 13825                   A lot less welcome now than last year
# 40913                 Just as welcome now as I felt last year
# 69049                 Just as welcome now as I felt last year
#
#                                          SONewContent   Age Gender Trans  \
# Respondent
# 28638                                             NaN   NaN    NaN   NaN
# 722                                               NaN   1.0    NaN   NaN
# 13825                                             NaN  56.0    NaN   NaN
# 40913       Tech articles written by other developers  22.0    Man    No
# 69049                                             NaN  34.0    Man    No
#
#                           Sexuality                     Ethnicity Dependents  \
# Respondent
# 28638                           NaN                           NaN        NaN
# 722                             NaN                           NaN        NaN
# 13825                           NaN                           NaN        Yes
# 40913       Straight / Heterosexual                           NaN         No
# 69049       Straight / Heterosexual  White or of European descent         No
#
#                      SurveyLength SurveyEase
# Respondent
# 28638                    Too long        NaN
# 722                      Too long  Difficult
# 13825                   Too short       Easy
# 40913       Appropriate in length       Easy
# 69049       Appropriate in length       Easy

# %% [markdown]
# # Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df['SalaryUSD'].head()
# Out:
# Respondent
# 63129    1000000.0
# 50499     153216.0
# 39258      19152.0
# 58450      17556.0
# 7085       14364.0
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median()
# Out:
# 57287.0

# %%
df.median()
# Out:
# Hobbyist           1.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#            Hobbyist     CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean       0.801694  5.519014e+11  1.271107e+05     42.127197      5.084308
# std        0.398726  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        0.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%        1.000000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%        1.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%        1.000000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max        1.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['SalaryUSD'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# 1    71257
# 0    17626
# Name: Hobbyist, dtype: int64

# %%
schema_df.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %% [markdown]
# # groupby operation involves:
#     -split
#     -apply function
#     -combine results

# %%
df['Country'].value_counts()
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Papua New Guinea             1
# Tonga                        1
# Brunei Darussalam            1
# Niger                        1
# Sao Tome and Principe        1
# Name: Country, Length: 179, dtype: int64

# %%
country_grp = df.groupby(['Country'])
country_grp.get_group('Poland').head()
# Out:
#                                 MainBranch  Hobbyist  \
# Respondent
# 33348       I am a developer by profession         1
# 88225       I am a developer by profession         1
# 72753       I am a developer by profession         1
# 74331       I am a developer by profession         1
# 48226       I am a developer by profession         1
#
#                                                   OpenSourcer  \
# Respondent
# 33348       Less than once a month but more than once per ...
# 88225       Less than once a month but more than once per ...
# 72753                                 Less than once per year
# 74331                                 Less than once per year
# 48226       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 33348       OSS is, on average, of HIGHER quality than pro...
# 88225       OSS is, on average, of HIGHER quality than pro...
# 72753       The quality of OSS and closed source software ...
# 74331       OSS is, on average, of HIGHER quality than pro...
# 48226       The quality of OSS and closed source software ...
#
#                                                    Employment Country  \
# Respondent
# 33348                                      Employed full-time  Poland
# 88225                                      Employed full-time  Poland
# 72753       Independent contractor, freelancer, or self-em...  Poland
# 74331                                      Employed full-time  Poland
# 48226       Independent contractor, freelancer, or self-em...  Poland
#
#                    Student                                      EdLevel  \
# Respondent
# 33348                   No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88225                   No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 72753       Yes, full-time  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 74331                   No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 48226       Yes, full-time     Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 33348       Computer science, computer engineering, or sof...
# 88225       Computer science, computer engineering, or sof...
# 72753       Computer science, computer engineering, or sof...
# 74331       Another engineering discipline (ex. civil, ele...
# 48226       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 33348       Taken an online course in programming or softw...
# 88225       Taken an online course in programming or softw...
# 72753       Participated in a full-time developer training...
# 74331       Taken an online course in programming or softw...
# 48226       Taken a part-time in-person course in programm...
#
#                          OrgSize  \
# Respondent
# 33348       100 to 499 employees
# 88225         20 to 99 employees
# 72753       100 to 499 employees
# 74331       100 to 499 employees
# 48226         20 to 99 employees
#
#                                                       DevType YearsCode  \
# Respondent
# 33348       Developer, back-end;Developer, desktop or ente...        23
# 88225                                     Developer, back-end        19
# 72753       Developer, back-end;Developer, game or graphic...        15
# 74331                                   Developer, full-stack         4
# 48226       Developer, back-end;Developer, front-end;Devel...        11
#
#            Age1stCode YearsCodePro                           CareerSat  \
# Respondent
# 33348              10           12                      Very satisfied
# 88225              15           12  Neither satisfied nor dissatisfied
# 72753              15           11                  Slightly satisfied
# 74331              15            3                  Slightly satisfied
# 48226              11            5               Slightly dissatisfied
#
#                                         JobSat                MgrIdiot  \
# Respondent
# 33348                           Very satisfied          Very confident
# 88225       Neither satisfied nor dissatisfied  I don't have a manager
# 72753                           Very satisfied                     NaN
# 74331                           Very satisfied          Very confident
# 48226                       Slightly satisfied                     NaN
#
#             MgrMoney MgrWant  \
# Respondent
# 33348       Not sure     Yes
# 88225             No      No
# 72753            NaN     NaN
# 74331             No      No
# 48226            NaN     NaN
#
#                                                       JobSeek  \
# Respondent
# 33348            I am not interested in new job opportunities
# 88225            I am not interested in new job opportunities
# 72753            I am not interested in new job opportunities
# 74331            I am not interested in new job opportunities
# 48226       I’m not actively looking, but I am open to new...
#
#                      LastHireDate  \
# Respondent
# 33348               1-2 years ago
# 88225       More than 4 years ago
# 72753        Less than a year ago
# 74331        Less than a year ago
# 48226               1-2 years ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 33348                                                     NaN       No
# 88225       Write any code;Complete a take-home project;In...       No
# 72753       Write any code;Complete a take-home project;In...       No
# 74331              Write code by hand (e.g., on a whiteboard)       No
# 48226       Write any code;Write code by hand (e.g., on a ...      Yes
#
#                                                    JobFactors  \
# Respondent
# 33348       Remote work options;Opportunities for professi...
# 88225       Remote work options;How widely used or impactf...
# 72753       Languages, frameworks, and other technologies ...
# 74331       Industry that I'd be working in;Languages, fra...
# 48226       Financial performance or funding status of the...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 33348       Something else changed (education, award, medi...            PLN
# 88225       Something else changed (education, award, medi...            PLN
# 72753                        I was preparing for a job search            PLN
# 74331                        I was preparing for a job search            PLN
# 48226                        I was preparing for a job search            PLN
#
#             CurrencyDesc  CompTotal CompFreq  SalaryUSD  WorkWeekHrs  \
# Respondent
# 33348       Polish zloty   178000.0  Monthly   570756.0         40.0
# 88225       Polish zloty    38700.0   Weekly   517050.0         43.0
# 72753       Polish zloty    35200.0   Weekly   470300.0         40.0
# 74331       Polish zloty   120000.0  Monthly   384780.0         40.0
# 48226       Polish zloty   110000.0  Monthly   352716.0         40.0
#
#                                                      WorkPlan  \
# Respondent
# 33348                                                     NaN
# 88225       There's no schedule or spec; I work on what se...
# 72753       There is a schedule and/or spec (made by me or...
# 74331       There is a schedule and/or spec (made by me or...
# 48226       There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 33348       Inadequate access to necessary tools;Toxic wor...
# 88225       Being tasked with non-development work;Distrac...
# 72753       Distracting work environment;Meetings;Non-work...
# 74331                                                     NaN
# 48226       Non-work commitments (parenting, school work, ...
#
#                                                    WorkRemote WorkLoc  \
# Respondent
# 33348       Less than half the time, but at least one day ...  Office
# 88225       All or almost all the time (I'm full-time remote)    Home
# 72753                                   A few days each month  Office
# 74331                        Less than once per month / Never  Office
# 48226                                   A few days each month  Office
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 33348       A little above average  Yes, because I see value in code review
# 88225                      Average  Yes, because I see value in code review
# 72753                      Average  Yes, because I see value in code review
# 74331       A little above average  Yes, because I see value in code review
# 48226       A little above average  Yes, because I see value in code review
#
#             CodeRevHrs                                          UnitTests  \
# Respondent
# 33348              2.0  Yes, it's not part of our process but the deve...
# 88225             10.0  Yes, it's not part of our process but the deve...
# 72753              5.0                                                NaN
# 74331              3.0  Yes, it's not part of our process but the deve...
# 48226              5.0                                                NaN
#
#                                                   PurchaseHow  \
# Respondent
# 33348       Developers typically have the most influence o...
# 88225       Developers typically have the most influence o...
# 72753                                                     NaN
# 74331       Developers and management have nearly equal in...
# 48226                                                     NaN
#
#                                 PurchaseWhat  \
# Respondent
# 33348                  I have some influence
# 88225       I have a great deal of influence
# 72753                                    NaN
# 74331          I have little or no influence
# 48226                                    NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 33348       Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 88225                                          Java;Scala;SQL
# 72753              Bash/Shell/PowerShell;C#;Go;JavaScript;SQL
# 74331                                       Python;TypeScript
# 48226       Assembly;Bash/Shell/PowerShell;C;C++;C#;HTML/C...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 33348       Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# 88225                                   Java;Python;Scala;SQL
# 72753              C#;Go;JavaScript;Kotlin;PHP;Rust;Scala;SQL
# 74331                                 C#;Go;Python;TypeScript
# 48226       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;K...
#
#                                        DatabaseWorkedWith  \
# Respondent
# 33348                                PostgreSQL;Other(s):
# 88225                Cassandra;MariaDB;MongoDB;PostgreSQL
# 72753       Microsoft SQL Server;Oracle;PostgreSQL;SQLite
# 74331                                                 NaN
# 48226                           MongoDB;PostgreSQL;SQLite
#
#                                       DatabaseDesireNextYear  \
# Respondent
# 33348                                              Other(s):
# 88225                   Cassandra;MariaDB;MongoDB;PostgreSQL
# 72753       Cassandra;Elasticsearch;MongoDB;PostgreSQL;Redis
# 74331                                                    NaN
# 48226                                      PostgreSQL;SQLite
#
#                                     PlatformWorkedWith  \
# Respondent
# 33348                                     Docker;Linux
# 88225                                      MacOS;Slack
# 72753       Android;Docker;iOS;Microsoft Azure;Windows
# 74331                            Google Cloud Platform
# 48226                   Android;AWS;Docker;Linux;Slack
#
#                                   PlatformDesireNextYear  \
# Respondent
# 33348                            Docker;Kubernetes;Linux
# 88225       AWS;Docker;Google Cloud Platform;MacOS;Slack
# 72753        AWS;Docker;Google Cloud Platform;Kubernetes
# 74331                       Docker;Google Cloud Platform
# 48226                           Android;AWS;Docker;Linux
#
#                                   WebFrameWorkedWith  \
# Respondent
# 33348       Angular/Angular.js;Express;Spring;Vue.js
# 88225                                         Spring
# 72753                                        ASP.NET
# 74331                      Angular/Angular.js;Django
# 48226                          Django;Flask;React.js
#
#                        WebFrameDesireNextYear  \
# Respondent
# 33348                   Express;Spring;Vue.js
# 88225                  React.js;Spring;Vue.js
# 72753                                     NaN
# 74331       Angular/Angular.js;ASP.NET;Django
# 48226                   Django;Flask;React.js
#
#                          MiscTechWorkedWith    MiscTechDesireNextYear  \
# Respondent
# 33348                       Ansible;Node.js           Ansible;Node.js
# 88225                                   NaN              Apache Spark
# 72753       .NET;.NET Core;Unity 3D;Xamarin  Hadoop;.NET Core;Node.js
# 74331                                   NaN                 .NET Core
# 48226               Ansible;Pandas;Unity 3D          Ansible;Unity 3D
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 33348                         Atom;Eclipse;Visual Studio Code  Linux-based
# 88225                                                IntelliJ        MacOS
# 72753       Android Studio;Atom;IntelliJ;Notepad++;Visual ...        MacOS
# 74331                                      Visual Studio Code  Linux-based
# 48226       Android Studio;Atom;IntelliJ;IPython / Jupyter...  Linux-based
#
#                                                    Containers  \
# Respondent
# 33348       Development;Testing;Outside of work, for perso...
# 88225                                     Development;Testing
# 72753                          Development;Testing;Production
# 74331                                             Development
# 48226                                     Development;Testing
#
#                                          BlockchainOrg  \
# Respondent
# 33348          Non-currency applications of blockchain
# 88225       Implementing cryptocurrency-based products
# 72753                                              NaN
# 74331                                       Not at all
# 48226                                              NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 33348                                                     NaN        Yes
# 88225       Useful for immutable record keeping outside of...        Yes
# 72753       Useful for immutable record keeping outside of...         No
# 74331                                                     NaN        Yes
# 48226                       An irresponsible use of resources        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 33348                                            NaN   Yes     YouTube
# 88225       Fortunately, someone else has that title   Yes     Twitter
# 72753                                       Also Yes   Yes     YouTube
# 74331                                           SIGH    No      Reddit
# 48226                                           SIGH   Yes    Facebook
#
#                         Extraversion ScreenName SOVisit1st  \
# Respondent
# 33348       In real life (in person)   Username       2013
# 88225       In real life (in person)      Login       2009
# 72753       In real life (in person)   Username       2010
# 74331       In real life (in person)   Username       2014
# 48226       In real life (in person)   Username       2011
#
#                       SOVisitFreq  \
# Respondent
# 33348       Daily or almost daily
# 88225        A few times per week
# 72753       Daily or almost daily
# 74331        A few times per week
# 48226       Daily or almost daily
#
#                                                     SOVisitTo  \
# Respondent
# 33348       Find answers to specific questions;Pass the ti...
# 88225                      Find answers to specific questions
# 72753       Find answers to specific questions;Contribute ...
# 74331       Find answers to specific questions;Learn how t...
# 48226                      Find answers to specific questions
#
#                        SOFindAnswer                         SOTimeSaved  \
# Respondent
# 33348            3-5 times per week  Stack Overflow was slightly faster
# 88225       Less than once per week  Stack Overflow was slightly faster
# 72753           6-10 times per week  Stack Overflow was slightly faster
# 74331       Less than once per week      Stack Overflow was much faster
# 48226            1-2 times per week            They were about the same
#
#             SOHowMuchTime SOAccount  \
# Respondent
# 33348       11-30 minutes       Yes
# 88225       11-30 minutes       Yes
# 72753         60+ minutes       Yes
# 74331       11-30 minutes       Yes
# 48226                 NaN       Yes
#
#                                                    SOPartFreq  \
# Respondent
# 33348                     Less than once per month or monthly
# 88225                     Less than once per month or monthly
# 72753                                   Daily or almost daily
# 74331                     Less than once per month or monthly
# 48226       I have never participated in Q&A on Stack Over...
#
#                                                        SOJobs  \
# Respondent
# 33348       No, I knew that Stack Overflow had a job board...
# 88225       No, I knew that Stack Overflow had a job board...
# 72753                                                     Yes
# 74331       No, I didn't know that Stack Overflow had a jo...
# 48226       No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams          SOComm  \
# Respondent
# 33348       No, I've heard of them, but I am not part of a...   Yes, somewhat
# 88225                                                     Yes  No, not really
# 72753       No, I've heard of them, but I am not part of a...   Yes, somewhat
# 74331                     No, and I don't know what those are         Neutral
# 48226       No, I've heard of them, but I am not part of a...   Yes, somewhat
#
#                                        WelcomeChange  \
# Respondent
# 33348       Somewhat less welcome now than last year
# 88225        Just as welcome now as I felt last year
# 72753        Just as welcome now as I felt last year
# 74331        Just as welcome now as I felt last year
# 48226        Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 33348                                                     NaN  33.0    Man
# 88225       Tech articles written by other developers;Indu...  39.0    Man
# 72753            Courses on technologies you're interested in  33.0    Man
# 74331                     Tech meetups or events in your area  18.0    Man
# 48226       Tech articles written by other developers;Indu...  24.0    Man
#
#            Trans                Sexuality                     Ethnicity  \
# Respondent
# 33348         No  Straight / Heterosexual  White or of European descent
# 88225         No  Straight / Heterosexual                Middle Eastern
# 72753         No  Straight / Heterosexual  White or of European descent
# 74331         No  Straight / Heterosexual  White or of European descent
# 48226         No  Straight / Heterosexual  White or of European descent
#
#            Dependents           SurveyLength                  SurveyEase
# Respondent
# 33348             Yes  Appropriate in length                        Easy
# 88225             Yes  Appropriate in length                        Easy
# 72753             Yes  Appropriate in length                        Easy
# 74331              No  Appropriate in length                        Easy
# 48226              No  Appropriate in length  Neither easy nor difficult

# %%
filt = df['Country'] == 'Poland'
df.loc[filt]['SocialMedia'].value_counts(normalize=True)
# Out:
# Facebook                    0.339923
# YouTube                     0.200988
# Reddit                      0.141680
# I don't use social media    0.098847
# Twitter                     0.090060
# Instagram                   0.047227
# LinkedIn                    0.039539
# WhatsApp                    0.035146
# Snapchat                    0.003844
# VK ВКонта́кте               0.002197
# Hello                       0.000549
# Name: SocialMedia, dtype: float64

# %%
country_grp['SocialMedia'].value_counts()
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    15
#              YouTube                      9
#              I don't use social media     6
#              WhatsApp                     4
#              Instagram                    1
#                                          ..
# Zimbabwe     Facebook                     3
#              YouTube                      3
#              Instagram                    2
#              LinkedIn                     2
#              Reddit                       1
# Name: SocialMedia, Length: 1220, dtype: int64

# %%
country_grp['SocialMedia'].value_counts().loc['China']
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: SocialMedia, dtype: float64

# %%
country_grp['SalaryUSD'].median().tail()
# Out:
# Country
# Venezuela, Bolivarian Republic of...     6384.0
# Viet Nam                                11892.0
# Yemen                                   11940.0
# Zambia                                   5040.0
# Zimbabwe                                19200.0
# Name: SalaryUSD, dtype: float64

# %%
country_grp['SalaryUSD'].median().loc['Poland']
# Out:
# 32064.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['Poland']
# Out:
# median    32064.000000
# mean      38860.441332
# Name: Poland, dtype: float64

# %%
filt = df['Country'] == 'Poland'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    1156
# True      751
# Name: LanguageWorkedWith, dtype: int64

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-243-a0b6d43d6dcb> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').value_counts()
#
# ~/.virtualenvs/sof_env/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda s: s.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# - What % of people from each country know Python?

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Papua New Guinea             1
# Tonga                        1
# Brunei Darussalam            1
# Niger                        1
# Sao Tome and Principe        1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda s: s.str.contains('Python').sum())

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns')
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df['PctKnowsPython'] = (python_df['NumKnowsPython'] / python_df['NumRespondents']) * 100
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.loc['Poland']
# Out:
# NumRespondents    1922.000000
# NumKnowsPython     751.000000
# PctKnowsPython      39.073881
# Name: Poland, dtype: float64

# %% [markdown]
# # Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCodePro'].unique()
# Out:
# array([nan, '1', 'Less than 1 year', '9', '3', '4', '10', '8', '2', '13',
#        '18', '5', '14', '22', '23', '19', '35', '20', '25', '7', '15',
#        '27', '6', '48', '12', '31', '11', '17', '16', '21', '29', '30',
#        '26', '33', '28', '37', '40', '34', '24', '39', '38', '36', '32',
#        '41', '45', '43', 'More than 50 years', '44', '42', '46', '49',
#        '50', '47'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCodePro'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)
df['YearsCodePro'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
df['YearsCodePro'].unique()
# Out:
# array([nan, '1', 0, '9', '3', '4', '10', '8', '2', '13', '18', '5', '14',
#        '22', '23', '19', '35', '20', '25', '7', '15', '27', '6', '48',
#        '12', '31', '11', '17', '16', '21', '29', '30', '26', '33', '28',
#        '37', '40', '34', '24', '39', '38', '36', '32', '41', '45', '43',
#        51, '44', '42', '46', '49', '50', '47'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCodePro'] = df['YearsCodePro'].astype(float)

# %%
print(f"mean YearsCode: {df['YearsCode'].mean():.2f}")
print(f"median YearsCode: {df['YearsCode'].median()}")
print(f"mean YearsCodePro: {df['YearsCodePro'].mean():.2f}")
print(f"median YearsCodePro: {df['YearsCodePro'].median()}")
# Out:
# mean YearsCode: 11.66
# median YearsCode: 9.0
# mean YearsCodePro: 8.16
# median YearsCodePro: 6.0
